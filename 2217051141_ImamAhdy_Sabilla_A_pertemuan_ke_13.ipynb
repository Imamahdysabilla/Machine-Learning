# %% [markdown]
# <a href="https://colab.research.google.com/github/Imamahdysabilla/Machine-Learning/blob/main/2217051141_ImamAhdy_Sabilla_A_pertemuan_ke_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rahmantaufik27/dataset/main/study/weather_nb_dataset.csv")
df
# Out:
#      Outlook  Temp Humidity Windy Play
# 0      Rainy   Hot     High     f   no
# 1      Rainy   Hot     High     t   no
# 2   Overcast   Hot     High     f  yes
# 3      Sunny  Mild     High     f  yes
# 4      Sunny  Cool   Normal     f  yes
# 5      Sunny  Cool   Normal     t   no
# 6   Overcast  Cool   Normal     t  yes
# 7      Rainy  Mild     High     f   no
# 8      Rainy  Cool   Normal     f  yes
# 9      Sunny  Mild   Normal     f  yes
# 10     Rainy  Mild   Normal     t  yes
# 11  Overcast  Mild     High     t  yes
# 12  Overcast   Hot   Normal     f  yes
# 13     Sunny  Mild     High     t   no
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Outlook').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Temp').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Humidity').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Windy').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Temp'].value_counts()
#     for x_label, grp in df.groupby('Outlook')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Outlook')
# _ = plt.ylabel('Temp')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Humidity'].value_counts()
#     for x_label, grp in df.groupby('Temp')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Temp')
# _ = plt.ylabel('Humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Windy'].value_counts()
#     for x_label, grp in df.groupby('Humidity')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Humidity')
# _ = plt.ylabel('Windy')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Play'].value_counts()
#     for x_label, grp in df.groupby('Windy')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Windy')
# _ = plt.ylabel('Play')

# %% [markdown]
# # Preprocessing

# %%
# pisahkan data target
X_train = df.drop('Play', axis='columns')
y_train = df['Play']

# %% [markdown]
# # Encoding Data

# %%
# buat dataFrame baru dengan encoding data
numerics = LabelEncoder()
X_train['outlook_n'] = numerics.fit_transform(X_train['Outlook'])
X_train['Temp_n'] = numerics.fit_transform(X_train['Temp'])
X_train['Humidity_n'] = numerics.fit_transform(X_train['Humidity'])
X_train['windy_n'] = numerics.fit_transform(X_train['Windy'])
X_train = X_train.drop(['Outlook', 'Temp', 'Humidity', 'Windy'],axis='columns')
X_train
# Out:
#     outlook_n  Temp_n  Humidity_n  windy_n
# 0           1       1           0        0
# 1           1       1           0        1
# 2           0       1           0        0
# 3           2       2           0        0
# 4           2       0           1        0
# 5           2       0           1        1
# 6           0       0           1        1
# 7           1       2           0        0
# 8           1       0           1        0
# 9           2       2           1        0
# 10          1       2           1        1
# 11          0       2           0        1
# 12          0       1           1        0
# 13          2       2           0        1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X_train['outlook_n'].plot(kind='hist', bins=20, title='outlook_n')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['Temp_n'].plot(kind='hist', bins=20, title='Temp_n')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['Humidity_n'].plot(kind='hist', bins=20, title='Humidity_n')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['windy_n'].plot(kind='hist', bins=20, title='windy_n')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X_train.plot(kind='scatter', x='outlook_n', y='Temp_n', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X_train.plot(kind='scatter', x='Temp_n', y='Humidity_n', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# X_train.plot(kind='scatter', x='Humidity_n', y='windy_n', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# X_train['outlook_n'].plot(kind='line', figsize=(8, 4), title='outlook_n')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['Temp_n'].plot(kind='line', figsize=(8, 4), title='Temp_n')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['Humidity_n'].plot(kind='line', figsize=(8, 4), title='Humidity_n')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# X_train['windy_n'].plot(kind='line', figsize=(8, 4), title='windy_n')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Modelling

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Evaluation

# %%
nb.score(X_train, y_train)
# Out:
# 0.8571428571428571
